# %%
import numpy as np

# %%
import pandas as pd

# %%
f1 = pd.read_excel('C:/Users/ivanr/OneDrive/Radna površina/files_for_activites103/file1_customer1.xlsx')

# %%
f1.head()
# Out:
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#    income  monthly premium auto number of open complaints     policy type  \
# 0       0                  1000                    1/0/00   Personal Auto
# 1       0                    94                    1/0/00   Personal Auto
# 2   48767                   108                    1/0/00   Personal Auto
# 3       0                   106                    1/0/00  Corporate Auto
# 4   36357                    68                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
f1.shape
# Out:
# (1071, 11)

# %%
f2 = pd.read_excel('C:/Users/ivanr/OneDrive/Radna površina/files_for_activites103/file2_customer1.xlsx')

# %%
f2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
f2.shape
# Out:
# (996, 11)

# %%
f3 = pd.read_excel('C:/Users/ivanr/OneDrive/Radna površina/files_for_activites103/file3 _customer1.xlsx')

# %%
f3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
f1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
f2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
f3.columns
# Out:
# Index(['customer', 'state', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
f3.shape
# Out:
# (7070, 11)

# %%
new_names = []
for col in f1.columns:
    new_names.append(col.lower())

# %%
f1.columns = new_names

# %%
new_names = []
for col in f2.columns:
    new_names.append(col.lower())

# %%
f2.columns = new_names

# %%
new_names = []
for col in f3.columns:
    new_names.append(col.lower())

# %%
f3.columns = new_names

# %%
f1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
f2.columns = ['customer', 'st', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']

# %%
f2.head()
# Out:
#   customer          st gender education customer lifetime value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly premium auto number of open complaints  policy type  \
# 0                    88                    1/0/00        633.6
# 1                   114                    1/0/00        547.2
# 2                   112                    1/0/00        537.6
# 3                   214                    1/1/00       1027.2
# 4                    94                    1/0/00        451.2
#
#     vehicle class total claim amount
# 0   Personal Auto      Four-Door Car
# 1    Special Auto                SUV
# 2   Personal Auto       Two-Door Car
# ...

# %%
f3.columns = ['customer', 'st', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']

# %%
f3.head()
# Out:
#   customer          st       gender             education  \
# 0  SA25987  Washington  3479.137523  High School or Below
# 1  TB86706     Arizona  2502.637401                Master
# 2  ZL73902      Nevada  3265.156348              Bachelor
# 3  KX23516  California  4455.843406  High School or Below
# 4  FN77294  California  7704.958480  High School or Below
#
#   customer lifetime value  income  monthly premium auto  \
# 0                       M       0                   104
# 1                       M       0                    66
# 2                       F   25820                    82
# 3                       F       0                   121
# 4                       M   30366                   101
#
#    number of open complaints    policy type  vehicle class total claim amount
# 0                          0  Personal Auto     499.200000       Two-Door Car
# 1                          0  Personal Auto       3.468912       Two-Door Car
# ...

# %%
data_concat = pd.concat([f1, f2, f3], axis = 0)

# %%
data_concat.shape
# Out:
# (9137, 11)

# %%
data_concat.dtypes
# Out:
# customer                     object
# st                           object
# gender                       object
# education                    object
# customer lifetime value      object
# income                        int64
# monthly premium auto          int64
# number of open complaints    object
# policy type                  object
# vehicle class                object
# total claim amount           object
# dtype: object

# %%
data_concat.drop(['education', 'number of open complaints'], axis = 1)
# Out:
#      customer          st       gender customer lifetime value  income  \
# 0     RB50392  Washington          NaN                     NaN       0
# 1     QZ44356     Arizona            F              697953.59%       0
# 2     AI49188      Nevada            F             1288743.17%   48767
# 3     WW63253  California            M              764586.18%       0
# 4     GA49547  Washington            M              536307.65%   36357
# ...       ...         ...          ...                     ...     ...
# 7065  LA72316  California  23405.98798                       M   71941
# 7066  PK87824  California  3096.511217                       F   21604
# 7067  TD14365  California  8163.890428                       M       0
# 7068  UP19263  California  7524.442436                       M   21941
# 7069  Y167826  California  2611.836866                       M       0
#
#       monthly premium auto     policy type  vehicle class total claim amount
# ...

# %%
data_concat['customer lifetime value'] = data_concat['customer lifetime value']*100

# %%
data_concat['customer lifetime value'] = pd.to_numeric(data_concat['customer lifetime value'], errors = 'coerce')

# %%
data_concat.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value      float64
# income                         int64
# monthly premium auto           int64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount            object
# dtype: object

# %%
data_concat.drop_duplicates()
# Out:
#      customer          st       gender             education  \
# 0     RB50392  Washington          NaN                Master
# 1     QZ44356     Arizona            F              Bachelor
# 2     AI49188      Nevada            F              Bachelor
# 3     WW63253  California            M              Bachelor
# 4     GA49547  Washington            M  High School or Below
# ...       ...         ...          ...                   ...
# 7065  LA72316  California  23405.98798              Bachelor
# 7066  PK87824  California  3096.511217               College
# 7067  TD14365  California  8163.890428              Bachelor
# 7068  UP19263  California  7524.442436               College
# 7069  Y167826  California  2611.836866               College
#
#       customer lifetime value  income  monthly premium auto  \
# 0                         NaN       0                  1000
# 1                         NaN       0                    94
# ...

# %%
data_concat.shape
# Out:
# (9137, 11)

# %%
data_concat.filter(data_concat['income'] == 0 & data_concat['income'] < 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 data_concat.filter(data_concat['income'] == 0 & data_concat['income'] < 0)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
data_concat[data_concat['income']<=0]
# Out:
#      customer          st       gender             education  \
# 0     RB50392  Washington          NaN                Master
# 1     QZ44356     Arizona            F              Bachelor
# 3     WW63253  California            M              Bachelor
# 7     CF85061     Arizona            M                Master
# 10    SX51350  California            M               College
# ...       ...         ...          ...                   ...
# 7059  WZ45103  California  5678.050167              Bachelor
# 7061  RX91025  California    19872.262  High School or Below
# 7062  AC13887  California  4628.995325              Bachelor
# 7067  TD14365  California  8163.890428              Bachelor
# 7069  Y167826  California  2611.836866               College
#
#       customer lifetime value  income  monthly premium auto  \
# 0                         NaN       0                  1000
# 1                         NaN       0                    94
# ...

# %%
# Out:
# (0, 11)
