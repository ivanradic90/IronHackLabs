# %%
import pandas as pd

# %%
import numpy as np

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel('C:/Users/ivanr/OneDrive/Radna površina/files_for_activites103/marketing_customer_analysis.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     10910 non-null  float64
#  1   Customer                       10910 non-null  object
#  2   State                          10279 non-null  object
#  3   Customer Lifetime Value        10910 non-null  float64
#  4   Response                       10279 non-null  object
#  5   Coverage                       10910 non-null  object
#  6   Education                      10910 non-null  object
#  7   Effective To Date              10910 non-null  datetime64[ns]
#  8   EmploymentStatus               10910 non-null  object
#  9   Gender                         10910 non-null  object
#  10  Income                         10910 non-null  float64
#  11  Location Code                  10910 non-null  object
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  Customer Lifetime Value        Income  \
# count  10910.000000             10910.000000  10910.000000
# mean    5454.500000              8018.241094  37536.284785
# std     3149.590053              6885.081434  30359.195670
# min        0.000000              1898.007675      0.000000
# 25%     2727.250000              4014.453113      0.000000
# 50%     5454.500000              5771.147235  33813.500000
# 75%     8181.750000              8992.779137  62250.750000
# max    10909.000000             83325.381190  99981.000000
#
#        Monthly Premium Auto  Months Since Last Claim  \
# count          10910.000000             10277.000000
# mean              93.196059                15.149071
# std               34.442532                10.080349
# min               61.000000                 0.000000
# 25%               68.000000                 6.000000
# 50%               83.000000                14.000000
# 75%              109.000000                23.000000
# ...

# %%
data.describe(include='all')
# Out:
#           Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# count   10910.000000    10910       10279             10910.000000    10279
# unique           NaN     9134           5                      NaN        2
# top              NaN  ID89933  California                      NaN       No
# freq             NaN        7        3552                      NaN     8813
# first            NaN      NaN         NaN                      NaN      NaN
# last             NaN      NaN         NaN                      NaN      NaN
# mean     5454.500000      NaN         NaN              8018.241094      NaN
# std      3149.590053      NaN         NaN              6885.081434      NaN
# min         0.000000      NaN         NaN              1898.007675      NaN
# 25%      2727.250000      NaN         NaN              4014.453113      NaN
# 50%      5454.500000      NaN         NaN              5771.147235      NaN
# ...

# %%
sns.countplot(x=df['Response'])
plt.show()

# %%
df['Sales Channel'].unique()
# Out:
# array(['Agent', 'Call Center', 'Branch', 'Web'], dtype=object)

# %%
sns.countplot('Response', hue = 'Sales Channel', data=df)
plt.show()

# %%
sns.barplot(x ='Response', y = 'Total Claim Amount', estimator = sum, data=df)
plt.show()

# %%
sns.barplot(x ='Response', y = 'Income', data=df)
plt.show()
